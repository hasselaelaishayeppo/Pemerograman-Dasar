# %% [markdown]
# <a href="https://colab.research.google.com/github/hasselaelaishayeppo/Pemerograman-Dasar/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Biodata Saya

nama = "Hassel"
tempat_lahir = "Jakarta"
tanggal_lahir = "20 july 2007"
umur = 19
jurusan = "RPE"
semester = 3
matakuliah = 'Pemerograman Dasar'
status_lulus = False
organisasi = "Polibatam English Club"
teman = "Nuy"


print (nama)
print (tempat_lahir)
print (tanggal_lahir)
print (umur)
print (jurusan)
print (semester)
print (matakuliah)
print (status_lulus)
print (organisasi)
print (teman)
# Out:
# Hassel
# Jakarta
# 20 july 2007
# 19
# RPE
# 3
# Pemerograman Dasar
# False
# Polibatam English Club
# Nuy
